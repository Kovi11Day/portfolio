# %% [markdown]
# # Location Mention Recognition - BERT Named-Entity Recognition
# This project involves developing an automated process for recognition of toponyms (place/ area/ street names) in microblogging posts. The aim is to help authorities determine specific locations to send resources such as medical aid, food.
#
# The microblogging data used will be Twitter (X) posts and a Location Mention Recognition system will be built.
#
# 0. Setup
# 1. Read Data
# 2. Clean Dataset
# 3. Classification using BERT NER
# 4. Evaluation

# %% [markdown]
# ## 0. Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# imports
import pandas as pd
import requests
from google.colab import userdata
import torch
from transformers import BertTokenizer, BertTokenizerFast, BertForTokenClassification, pipeline
import warnings
import re
import evaluate
from jiwer import wer
from parallel_pandas import ParallelPandas

# %%
if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# GPU is available

# %%
#initialize parallel-pandas
ParallelPandas.initialize(n_cpu=4, split_factor=4, disable_pr_bar=False)

# %%
# setup
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Read Data

# %%
train_df = pd.read_csv('/content/drive/MyDrive/data_challenges/zindi_microsoft_LMR_challenge/data/Train.csv')
train_df.head(3)
# Out:
#                  tweet_id  \
# 0  ID_1001136212718088192
# 1  ID_1001136696589631488
# 2  ID_1001136950345109504
#
#                                                                                                   text  \
# 0                                                                                                  NaN
# 1  Flash floods struck a Maryland city on Sunday, washing out streets and tossing cars like bath toys.
# 2                                     State of emergency declared for Maryland flooding:  via @YouTube
#
#        location
# 0  EllicottCity
# 1      Maryland
# 2      Maryland

# %%
test_df = pd.read_csv('/content/drive/MyDrive/data_challenges/zindi_microsoft_LMR_challenge/data/Test.csv')
test_df.head(3)
# Out:
#                  tweet_id  \
# 0  ID_1001154804658286592
# 1  ID_1001155505459486720
# 2  ID_1001155756371136512
#
#                                                                                                                                                                                                                                                                                  text
# 0  What is happening to the infrastructure in New England? It isnt global warming, its misappropriated funds being abused that shouldve been used maintaining their infrastructure that couldve protected them from floods! Like New Orleans. Their mayor went to ὄ7#Maryland #floods
# 1                                                                                                                                                   SOLDER MISSING IN FLOOD.. PRAY FOR EDDISON HERMOND! PRAY FOR ELLICOTT CITY, MARYLAND! #PrayForEddisonHermond #PrayForEllicottCity
# 2                                                                                                                                                                         RT @TIME: Police searching for missing person after devastating 1,000-year flood in Ellicott City, Maryland

# %% [markdown]
# ## 2. Clean Dataset

# %%
# drop NaN
train_df = train_df.dropna()

# %% [markdown]
# ## 3. Classification using BERT Named-Entity Recognition

# %%
# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-cased', use_fast=False)

model_ner = BertForTokenClassification.from_pretrained('dbmdz/bert-large-cased-finetuned-conll03-english').to('cuda')
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
bert_pipeline = pipeline("ner", model=model_ner, tokenizer=tokenizer, device=0, grouped_entities=True)

# %%
# extract only location entites from BERT NER results
def extract_location(text):
    if text == '':
      return ''

    result = bert_pipeline(text)
    element_location = ''

    for dic_element in result:
      if dic_element['entity_group']=='LOC' and dic_element['score']>0.8:
        element_location = element_location + dic_element['word'] + ' '

    return element_location.rstrip()

# %%
train_df['predicted_locations'] = train_df['text'].apply(lambda x: extract_location(x)) # 4mins

# %%
train_df.head(3)
# Out:
#                  tweet_id  \
# 1  ID_1001136696589631488
# 2  ID_1001136950345109504
# 3  ID_1001137334056833024
#
#                                                                                                                                                                                                                 text  \
# 1                                                                                                                Flash floods struck a Maryland city on Sunday, washing out streets and tossing cars like bath toys.
# 2                                                                                                                                                   State of emergency declared for Maryland flooding:  via @YouTube
# 3  Other parts of Maryland also saw significant damage from Sundays storms including this Baltimore city neighborhood, #Dundalk and #Catonsville. Rain totals spanned from 1 to 10 inches across Maryland:  #ECFlood
#
#              location                              predicted_locations
# 1            Maryland                                         Maryland
# 2            Maryland                                         Maryland
# 3  Baltimore Maryland  Maryland Baltimore Dundalk Catonsville Maryland

# %% [markdown]
# ## 4. Evaluation

# %%
print('percentage missing locations in labels:')
print(str((len(train_df[train_df['location']==''])/len(train_df))*100))

print('percentage missing locations in predictions:')
print(str((len(train_df[train_df['predicted_locations']==''])/len(train_df))*100))
# Out:
# percentage missing locations in labels:
# 0.0
# percentage missing locations in predictions:
# 16.153261878639547

# %%
wer = evaluate.load("wer")
word_error_rate = wer.compute(references=train_df['location'].tolist(), predictions=train_df['predicted_locations'].tolist())
print('word error rate: ' + str(word_error_rate))
# Out:
# word error rate: 0.5662942456001582

# %%
train_df.sample(20)
# Out:
#                      tweet_id  \
# 45785   ID_870318387712319488
# 69839   ID_913345638447886336
# 39610   ID_728961497179815936
# 65666   ID_910717683544592384
# 46041   ID_874589898350743552
# 41766   ID_768760370177708032
# 71062   ID_913928111066157056
# 1562   ID_1022584826828935168
# 9241   ID_1036242305731051520
# 13069  ID_1040712364788785152
# 72265   ID_914541348815962112
# 63693   ID_909388318244327424
# 63361   ID_909138410773688320
# 68636   ID_912448486628630528
# 42579   ID_783431566806568960
# 27094  ID_1111683215520079872
# 18383  ID_1062362903377076224
# 38979   ID_722168788200906752
# 39424   ID_728706133439840256
# 57288   ID_906551035438780416
#
#                                                                                                                                                                                                                                                                               text  \
# 45785                                                                                                                                                                  RT @ColomboPageNews: #Australia hands over flood aid to #SriLanka navy #srilanka #FloodSL @AusHCSriLanka  .
# 69839                                                                                                                                                                                             #HurricaneMaria victims from #PuertoRico arrive in #NJ  #njmorningshow @News12NJ
# 39610                                                                                                                                                                                         Celebs, PM Trudeau Offer Support For Those Affected By Fort McMurray Wildfire Crisis
# 65666                                                                                                                                                     Dozens of children and adults are still missing after a school collapsed in Mexico following a 7.1 magnitude earthquake:
# 46041                                                                                                                                                                #SriLanka was hit by the worst flood since 2003. Support @hfhslorg disaster response & rebuilding efforts at:
# 41766                                                                                                                                                                                                      Volunteers distributing food near #Amatrice #ItalyEarthquake #terremoto
# 71062                                                                                                                                    Help Hurricane Maria Puerto Rico victims: Drop off needed supplies at HORC or donate to the American Red Cross through the Towns website.
# 1562                                                                                                                                                                                                                   #Greece wildfire that killed 82 people was started by arson
# 9241                                                                              A time-lapse video of volunteers in Kochi loading back-to-home-kits, containing food and other essential items, to be distributed in flood-affected houses in the suburbs tonight. #KeralaFloods
# 13069                                                                                  HURRICANE YETI IS MAKING LANDFALL TONIGHT AT 9:30 in Belmont, NC! Friends Sports Bar is the place to be tonight! We got Beer, Food, Liquor and Wine! All the Hurricane Prep stuff you need.
# 72265                                                                                                                                                 #Donate #Earthquake #Relief for #Mexico Today until 10:00PM 625 H Street #ChulaVista All items & monetary donations accepted
# 63693                                                                                                                                 Safe after Irma and no real damage. However we still do not have power in Riverstone and left on Thursday staying with friends in Bradenton.
# 63361                                                                                                                                                                  Cleanup of national parks hammered by Hurricane Irma continues. @NPCA @NatParkTrust @GoParks #NationalParks
# 68636                                                                                                                                                                                                         Actress Salma Hayek gives $100,000 for Mexico earthquake relief  via
# 42579                                                                                                                                                                    #Cuba Haiti: The European Union brings relief to victims of hurricane Matthew in Haiti  #crisismanagement
# 27094  There are now 139 confirmed cases of cholera in Mozambique after Cyclone Idai. Doctors in Beira say they are seeing 200 suspected cases per day. People are being forced to drink contaminated water because the citys water supply is damaged, increasing risk of illness.
# 18383                                                                                                                                                                          Death toll passes 42 in northern California wildfire, now deadliest in states history  via @ABCNews
# 38979                                                                                                                                               RT @Diplomacy_Notes: Please help our friends in #Ecuador! Give something for #EcuadorEarthquake! With sympathy @EmbajadaEcuUSA
# 39424                                                                                                                                                  RT @iuoe115: IUOE 115 donating $115,000 to Union disaster fund to help IUOE 955 members affected by #FortMcMurray wildfire.
# 57288                                                                                                                                                 Right now Florida needs 1,000 volunteer shelter nurses. We need your help for our special needs shelters. -@FLGovScott #irma
#
#                           location   predicted_locations
# 45785  Australia srilanka SriLanka     Colombo Australia
# 69839                PuertoRico NJ
# 39610                Fort McMurray                 ##ray
# 65666                       Mexico                Mexico
# 46041                     SriLanka              SriLanka
# 41766                     Amatrice                 Italy
# 71062                  Puerto Rico           Puerto Rico
# 1562                        Greece                Greece
# 9241                         Kochi                 Kochi
# 13069                   Belmont NC            Belmont NC
# 72265          Mexico 625 H Street       Mexico H Street
# 63693         Bradenton Riverstone  Riverstone Bradenton
# 63361                NationalParks
# 68636                       Mexico                Mexico
# 42579                   Haiti Cuba      Cuba Haiti Haiti
# 27094             Mozambique Beira      Mozambique Beira
# 18383                   California            California
# 38979                      Ecuador               Ecuador
# 39424                 FortMcMurray
# 57288                      Florida               Florida

# %% [markdown]
# Using BERT pretrained Named Entity Recognition model gave the following results:
# - Percentage missing location: 16.15%
# - Word Error Rate: 0.566%
#
# The next step will be to fine-tune the BERT classification model.
